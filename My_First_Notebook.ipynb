# %% [markdown]
# # My first markdown cell in Jupyter

# %% [markdown]
# # Cell 1 is foundational coding (vairables, math operations, etc)

# %%
print ("Hello, World!")
print ("Exploring Jupyter notebooks with Python code.")

name = "Blessing"
print ("My name is", name)

age = 20 + 4
print ("I am", age, "years old.")

a = 100
b = 100

print('Addition:', a + b)
print('Subtraction:', a - b)
print('Multiplication:', a * b)
print('Division:', a / b)
# Out:
# Hello, World!
# Exploring Jupyter notebooks with Python code.
# My name is Blessing
# I am 24 years old.
# Addition: 200
# Subtraction: 0
# Multiplication: 10000
# Division: 1.0
